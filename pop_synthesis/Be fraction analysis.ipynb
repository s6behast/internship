# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 10, 8
import numpy as np 
import pickle
import glob 
import os 
import time , sys
from scipy import integrate
from cycler import cycler
from mpl_toolkits.mplot3d import Axes3D

from functions import read_dat2file

# %%
Be_fracdf=pd.read_pickle('be_frac.pk')


plt.plot(Be_fracdf['t/yr']/1e6, Be_fracdf['Be_frac'], '-o')
plt.ylabel('fraction of MS stars with v/vcrit > 0.7')
plt.title('MW Models ')
plt.xlabel('time/Myr')
plt.savefig(("Be_frac_evol.png"), dpi=300 ,bbox_inches='tight')
plt.show()
Be_fracdf.head()
# Out:
#            t/yr   Be_frac
# 0  0.000000e+00  0.004721
# 0  2.020202e+06  0.004809
# 0  4.040404e+06  0.004692
# 0  6.060606e+06  0.012978
# 0  8.080808e+06  0.017936
