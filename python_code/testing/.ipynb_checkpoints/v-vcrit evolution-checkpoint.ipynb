# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 8, 6
import numpy as np 
import glob 
import os

data_dir='/users/bhastings/internship/data/MW/'
file_ext= '.dat2'

# %%
data_files=sorted(sorted(glob.glob(data_dir +'*'+ file_ext)), key=len) 

print 'There are ', len(data_files), file_ext, ' files', '\nin directory ', data_dir



def read_file(f):
    model_name= f.split('/')[-1].rsplit('.',1)[0]
    wanted_cols=['1:t[s]', '2:M/Msun', '3:Teff[K]', '4:log(L/Lsun)','5:R/Rsun','6:log(Mdot)[Msun/yr]',
                 '8:v_crit[km/s]', '9:v_surf[km/s]','10:P[days]', '11:H','12:He','16:C', '17:N', '18:O', '26:H_massfr', '27:He_massfr']

    if "-0" in str(f): # if file is for NON rotating star, remove vrot and crit vel from col names 
            col_names= ['1:t[s]', '2:M/Msun', '3:Teff[K]', '4:log(L/Lsun)', '5:R/Rsun', '6:log(Mdot)[Msun/yr]', '7:logg[cgs]', 
                        '10:P[days]', '11:H', '12:He', '13:Li', '14:Be', '15:B', '16:C', '17:N', '18:O', 
                    '19:F', '20:Ne', '21:Na', '22:Mg', '23:Al', '24:Si', '25:Fe', '26:H_massfr', '27:He_massfr']
    else: 
        col_names= ['1:t[s]', '2:M/Msun', '3:Teff[K]', '4:log(L/Lsun)', '5:R/Rsun', '6:log(Mdot)[Msun/yr]', '7:logg[cgs]', '8:v_crit[km/s]', 
                '9:v_surf[km/s]', '10:P[days]', '11:H', '12:He', '13:Li', '14:Be', '15:B', '16:C', '17:N', '18:O', 
                '19:F', '20:Ne', '21:Na', '22:Mg', '23:Al', '24:Si', '25:Fe', '26:H_massfr', '27:He_massfr']

    df= pd.read_csv(f, delim_whitespace=True,comment='#', names=col_names, usecols=wanted_cols)
    return df, model_name


u='f15-250.mw.dat2'
df,n= read_file(data_dir+u)     
print df.columns
# Out:
# There are  206 .dat2  files
# in directory  /users/bhastings/internship/data/MW/
# Index([u'1:t[s]', u'2:M/Msun', u'3:Teff[K]', u'4:log(L/Lsun)', u'5:R/Rsun',
#        u'6:log(Mdot)[Msun/yr]', u'8:v_crit[km/s]', u'9:v_surf[km/s]',
#        u'10:P[days]', u'11:H', u'12:He', u'16:C', u'17:N', u'18:O',
#        u'26:H_massfr', u'27:He_massfr'],
#       dtype='object')

# %%
mass_list=[3,5,7, 9, 12, 15, 20, 25, 30,40, 50, 60, 80, 100 ] # list of model masses 




plt.clf()
for m in mass_list:
    plt.clf()
    target_mass=m
    
    for f in data_files:
        if f.find('f'+str(target_mass)+'-') !=-1: #if file name contains target mass
            
            if f.find('-0') == -1: # if file is rotator 
                df,mod_nam=read_file(f)
                
               

                df['critfrac'] = df['9:v_surf[km/s]']/df['8:v_crit[km/s]']

                x,y= [df['1:t[s]']/1e6, df['critfrac'] ]   
                plt.plot(x,y, '-')
                

            #
            

            #leg = plt.legend(fontsize = 'large', loc='upper right', bbox_to_anchor=(1.25, 1.0))
            #leg.set_title(("Initial " +r'$\frac{V}{V_{crit}}$'), prop = {'size':18})

            #plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),ncol=5, title=r'$\frac{V}{V_{crit}}$' ,prop={'size':18})

            #plt.xlim(4.2,4.5) H-burinng
            #plt.xlim(3.5,3.7) He-burning 
            
    plt.title(str( target_mass) +" $M_{\odot}$  models")
    plt.xlabel(r'$time/Myr$', size=16)
    plt.ylabel(r'$v/vcrit$',size=16)
    plt.ylim(0,1.1)
    
    #plt.show()
    plt.savefig(("./v_evol/v-vcrit/" +str(target_mass)+".png"), dpi=300 ,bbox_inches='tight')

# %%
mass_list=[3,5,7, 9, 12, 15, 20, 25, 30,40, 50, 60, 80, 100 ] # list of model masses 




plt.clf()
for m in mass_list:
    plt.clf()
    target_mass=m
    
    for f in data_files:
        if f.find('f'+str(target_mass)+'-') !=-1: #if file name contains target mass
            
            if f.find('-0') == -1: # if file is rotator 
                df,mod_nam=read_file(f)
                
               

                df['critfrac'] = df['9:v_surf[km/s]']/df['8:v_crit[km/s]']

                x,y= [df['1:t[s]']/1e6, df['9:v_surf[km/s]'] ]   
                plt.plot(x,y, '-')
                

            #
            

            #leg = plt.legend(fontsize = 'large', loc='upper right', bbox_to_anchor=(1.25, 1.0))
            #leg.set_title(("Initial " +r'$\frac{V}{V_{crit}}$'), prop = {'size':18})

            #plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),ncol=5, title=r'$\frac{V}{V_{crit}}$' ,prop={'size':18})

            #plt.gca().invert_xaxis() # invert xaxis 

            #plt.xlim(4.2,4.5) H-burinng
            #plt.xlim(3.5,3.7) He-burning 
            
    plt.title(str( target_mass) +" $M_{\odot}$  models")
    plt.xlabel(r'$time/Myr$', size=16)
    plt.ylabel(r'$vsurf$',size=16)
    #plt.ylim(0,1.1)
    
    #plt.show()
    plt.savefig(("~/internship/python_code/velocity_evolution/v_evol/v/" +str(target_mass)+".png"), dpi=300 ,bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-748c0325b7e6> in <module>()
#      42
#      43     #plt.show()
# ---> 44     plt.savefig(("~/internship/python_code/velocity_evolution/v_evol/v/" +str(target_mass)+".png"), dpi=300 ,bbox_inches='tight')
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /usr/lib/python2.7/dist-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# /usr/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# /usr/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     530         renderer.dpi = self.figure.dpi
#     531         if is_string_like(filename_or_obj):
# --> 532             filename_or_obj = open(filename_or_obj, 'wb')
#     533             close = True
#     534         else:
#
# IOError: [Errno 2] No such file or directory: '~/internship/python_code/velocity_evolution/v_evol/v/3.png'

# %%
mass_list=[3,5,7, 9, 12, 15, 20, 25, 30,40, 50, 60, 80, 100 ] # list of model masses 




plt.clf()
for m in mass_list:
    plt.clf()
    target_mass=m
    
    for f in data_files:
        if f.find('f'+str(target_mass)+'-') !=-1: #if file name contains target mass
            
            if f.find('-0') == -1: # if file is rotator 
                df,mod_nam=read_file(f)
                
               

                df['critfrac'] = df['9:v_surf[km/s]']/df['8:v_crit[km/s]']

                x,y= [df['1:t[s]']/1e6, df['6:log(Mdot)[Msun/yr]'] ]   
                plt.plot(x,y, '-')
                

            #
            

            #leg = plt.legend(fontsize = 'large', loc='upper right', bbox_to_anchor=(1.25, 1.0))
            #leg.set_title(("Initial " +r'$\frac{V}{V_{crit}}$'), prop = {'size':18})

            #plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),ncol=5, title=r'$\frac{V}{V_{crit}}$' ,prop={'size':18})

            #plt.gca().invert_xaxis() # invert xaxis 

            #plt.xlim(4.2,4.5) H-burinng
            #plt.xlim(3.5,3.7) He-burning 
            
    plt.title(str( target_mass) +" $M_{\odot}$  models")
    plt.xlabel(r'$time/Myr$', size=16)
    plt.ylabel(r'$vcrit$',size=16)
    #plt.ylim(0,1.1)
    
    plt.show()
    #os.system("mkdir ./v_evol/v_crit/")
    #plt.savefig(("./v_evol/v_crit/" +str(target_mass)+".png"), dpi=300 ,bbox_inches='tight')

# %%
mass_list=[3,5,7, 9, 12, 15, 20, 25, 30,40, 50, 60, 80, 100 ] # list of model masses 



# %matplotlib qt
plt.clf()
for m in mass_list[0:1]:
    plt.clf()
    target_mass=9
    
    for f in data_files:
        if f.find('f'+str(target_mass)+'-') !=-1: #if file name contains target mass
            
            if f.find('-0') == -1: # if file is rotator 
                df,mod_nam=read_file(f)
                
               

                df['critfrac'] = df['9:v_surf[km/s]']/df['8:v_crit[km/s]']
                
                NdivH=10**(df['17:N']-12)
                CdivH= 10**(df['16:C']-12)
                x,y= [df['critfrac'], (NdivH/CdivH)/((NdivH/CdivH )[0]) ]   
                plt.plot(x[0:int(4e3)],y[0:int(4e3)], '-')
                

            #
            

            #leg = plt.legend(fontsize = 'large', loc='upper right', bbox_to_anchor=(1.25, 1.0))
            #leg.set_title(("Initial " +r'$\frac{V}{V_{crit}}$'), prop = {'size':18})

            #plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),ncol=5, title=r'$\frac{V}{V_{crit}}$' ,prop={'size':18})

            #plt.gca().invert_xaxis() # invert xaxis 

            #plt.xlim(4.2,4.5) H-burinng
            #plt.xlim(3.5,3.7) He-burning 
            
    plt.title(str( target_mass) +" $M_{\odot}$  models")
    plt.xlabel(r'$v/vcrit$', size=16)
    plt.ylabel(r'$(N/C) /(N/C)init $',size=16)
    #plt.ylim(0,1.1)
    
    plt.show()
    #os.system("mkdir ./v_evol/v_crit/")
    #plt.savefig(("./v_evol/v_crit/" +str(target_mass)+".png"), dpi=300 ,bbox_inches='tight')
