# %%
import numpy as np
import RichLucy as RL
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def P(x, eta):
    """x= v, eta= vsini. returns conditional probability of vsini, given v for randomly distributed i """
    if eta > x:
        return x*eta/ (eta * np.sqrt(eta**2- x**2))
    
    else:
        return 0

# %%
def iter_step(prev):
  updated_value = <function from Wikipedia>
  return updated_value

def iterate(initial_guess):
  cur = initial_guess
  while True:
    prev, cur = cur, iter_step(cur)
    if difference(prev, cur) <= tolerance:
      break
  return cur

# %%
# Out:
# Result of bandpass check:
# wavelength scale values are strictly monotonically increasing?	'True'
# wavelength scale values are spaced equidistantly?	'False'
# bandpass is normalized?	'False (integral = 2.7486e-09)'
# wavelength scale axis (minimum) spacing is:	 0.0485
#
# Result of checkSpectrum:
# wavelength scale values are strictly monotonically increasing?	'True'
# wavelength scale values are spaced equidistantly?	'False'
# wavelength scale (minimal) spacing: 	 1.9918
#
# Fixing input data:
#
# Check for equidistant wavelength scale axis
# Wavelength scale is not equidistant.New wavelength scale step size is 0.0485. Interpolating...
# Interpolation resulted in 0 NaN(s) and 0 negative value(s).
# Check for equidistant wavelength scale axis
#
# Wavelength step size in measured spectrum requires interpolation.
# New step size is 0.0485. Interpolating...
# Interpolation resulted in 0 NaN(s) and 0 negative value(s).
#
#
# Fixing of input data finished

# %%
S
# Out:
#  -------------- Richardson-Lucy algorithm version 2.0 --------------
# No stopping rule defined. Taking maximum number of iterations instead.
# Richardson-Lucy method with 500 iterations
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# . Done.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-498b67395cf2> in <module>()
# ----> 1 Shat,RMS,CURV = RL.RichLucy(b,delta,M,maxiter=500)
#
# ValueError: too many values to unpack

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-424caf2506b5> in <module>()
#       1 figure(1,figsize=(10,6))
#       2 plot(lM,M,label="measured spectrum")
# ----> 3 plot(lM,Shat,label="estimated spectrum")
#       4 xlim(630,670)
#       5 xlabel("wavelength / nm"); ylabel("spectrum amplitude / au")
#
# NameError: name 'Shat' is not defined
